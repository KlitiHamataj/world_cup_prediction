# %%
from src.features import build_training_features
df = build_training_features()
# Out:
# Built 15,872 training samples with 34 features

# %%
df = build_training_features()
df.to_csv("data/training_features.csv", index=False)
# Out:
# Built 15,872 training samples with 34 features

# %%
df.to_csv("data/training_features.csv", index=False)

# %%
import pandas as pd
df = pd.read_csv("data/training_features.csv")

# %%
df.shape
# Out:
# (15872, 34)

# %%
df.tail(10)
# Out:
#              date    home_team     away_team      tournament  neutral result  \
# 15862  2026-06-21        Spain  Saudi Arabia  FIFA World Cup        1   HOME
# 15863  2026-06-21      Uruguay    Cape Verde  FIFA World Cup        1   DRAW
# 15864  2026-06-21      Ecuador       Curaçao  FIFA World Cup        1   DRAW
# 15865  2026-06-22    Argentina       Austria  FIFA World Cup        1   HOME
# 15866  2026-06-22  New Zealand         Egypt  FIFA World Cup        1   AWAY
# 15867  2026-06-22       France          Iraq  FIFA World Cup        1   HOME
# 15868  2026-06-23       Norway       Senegal  FIFA World Cup        1   HOME
# 15869  2026-06-23     Portugal    Uzbekistan  FIFA World Cup        1   HOME
# 15870  2026-06-23       Jordan       Algeria  FIFA World Cup        1   AWAY
# 15871  2026-06-23      England         Ghana  FIFA World Cup        1   DRAW
#
#        home_ranking  away_ranking  ranking_diff  home_elo  ...  away_form_gf  \
# 15862           2.0          57.0          55.0    2165.0  ...             6
# 15863          17.0          70.0          53.0    1892.0  ...             6
# 15864          24.0          81.0          57.0    1933.0  ...             7
# 15865           3.0          23.0          20.0    2113.0  ...            13
# 15866          95.0          29.0         -66.0    1585.0  ...             7
# 15867           1.0          61.0          60.0    2081.0  ...             5
# 15868          44.0          14.0         -30.0    1912.0  ...             8
# 15869           5.0          62.0          57.0    1984.0  ...             3
# 15870          68.0          36.0         -32.0    1690.0  ...             5
# 15871           4.0          65.0          61.0    2020.0  ...             4
#
#        away_form_ga  away_form_gd  h2h_matches  h2h_home_wins  h2h_away_wins  \
# 15862             5             1            3              3              0
# 15863             8            -2            0              0              0
# 15864            18           -11            0              0              0
# 15865             3            10            2              1              0
# 15866             3             4            3              0              2
# 15867             8            -3            0              0              0
# 15868             7             1            1              0              1
# 15869            10            -7            0              0              0
# 15870             6            -1            2              0              1
# 15871            10            -6            1              0              0
#
#        h2h_draws  home_days_rest  away_days_rest  is_world_cup
# 15862          0               6               6             1
# 15863          0               6               6             1
# 15864          0               7               7             1
# 15865          1               5               5             1
# 15866          1               6               7             1
# 15867          0               6               6             1
# 15868          0               7               7             1
# 15869          0               6               5             1
# 15870          1               6               6             1
# 15871          1               6               6             1
#
# [10 rows x 34 columns]

# %%
df.head()
# Out:
#          date home_team    away_team tournament  neutral result  home_ranking  \
# 0  2010-01-02      Iran  North Korea   Friendly        1   HOME          21.0
# 1  2010-01-02     Qatar         Mali   Friendly        0   DRAW          35.0
# 2  2010-01-02     Syria     Zimbabwe   Friendly        1   HOME           NaN
# 3  2010-01-02     Yemen   Tajikistan   Friendly        0   AWAY           NaN
# 4  2010-01-03    Angola       Gambia   Friendly        1   DRAW           NaN
#
#    away_ranking  ranking_diff  home_elo  ...  away_form_gf  away_form_ga  \
# 0           NaN           NaN    1760.0  ...            11             4
# 1           NaN          65.0    1425.0  ...             6             5
# 2           NaN           0.0       NaN  ...             7             7
# 3           NaN           0.0       NaN  ...             7            11
# 4           NaN           NaN       NaN  ...             5             2
#
#    away_form_gd  h2h_matches  h2h_home_wins  h2h_away_wins  h2h_draws  \
# 0             7           10              8              0          2
# 1             1            0              0              0          0
# 2             0            0              0              0          0
# 3            -4            1              1              0          0
# 4             3            0              0              0          0
#
#    home_days_rest  away_days_rest  is_world_cup
# 0               3               3             0
# 1               3               3             0
# 2               3               4             0
# 3               3               3             0
# 4               4             180             0
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'tournament', 'neutral', 'result',
#        'home_ranking', 'away_ranking', 'ranking_diff', 'home_elo', 'away_elo',
#        'elo_diff', 'home_squad_age', 'away_squad_age', 'home_market_value',
#        'away_market_value', 'market_value_ratio', 'home_form_win_rate',
#        'home_form_pts_rate', 'home_form_gf', 'home_form_ga', 'home_form_gd',
#        'away_form_win_rate', 'away_form_pts_rate', 'away_form_gf',
#        'away_form_ga', 'away_form_gd', 'h2h_matches', 'h2h_home_wins',
#        'h2h_away_wins', 'h2h_draws', 'home_days_rest', 'away_days_rest',
#        'is_world_cup'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 34

# %%
from src.db import get_db, queries
import pandas as pd

with get_db() as conn:
    # New match results from the API
    print(queries.finished_matches(conn))

    # Odds that were just fetched
    print(queries.latest_odds(conn))

    # Team form stats
    print(pd.read_sql_query("SELECT * FROM team_stats LIMIT 10", conn))

    # Pipeline run log — shows every job and whether it succeeded
    print(pd.read_sql_query("SELECT * FROM pipeline_log ORDER BY finished_at DESC LIMIT 10", conn))
# Out:
#           date        stage group_name       home_team  \
# 0   2026-06-11  Group Stage          A          Mexico
# 1   2026-06-12  Group Stage          B          Canada
# 2   2026-06-12  Group Stage    GROUP A     South Korea
# 3   2026-06-13  Group Stage          B           Qatar
# 4   2026-06-13  Group Stage          C          Brazil
# 5   2026-06-13  Group Stage    GROUP D   United States
# 6   2026-06-14  Group Stage          E         Germany
# 7   2026-06-14  Group Stage          E   Côte d'Ivoire
# 8   2026-06-14  Group Stage          F     Netherlands
# 9   2026-06-14  Group Stage    GROUP C           Haiti
# 10  2026-06-14  Group Stage    GROUP D       Australia
# 11  2026-06-15  Group Stage          G         Belgium
# 12  2026-06-15  Group Stage          H           Spain
# 13  2026-06-15  Group Stage          H    Saudi Arabia
# 14  2026-06-15  Group Stage    GROUP F          Sweden
# 15  2026-06-16  Group Stage          I          France
# 16  2026-06-16  Group Stage          I            Iraq
# 17  2026-06-16  Group Stage    GROUP G            Iran
# 18  2026-06-17  Group Stage          J         Austria
# 19  2026-06-17  Group Stage          K        Portugal
# 20  2026-06-17  Group Stage          L         England
# 21  2026-06-17  Group Stage          L           Ghana
# 22  2026-06-17  Group Stage    GROUP J       Argentina
# 23  2026-06-18  Group Stage          A  Czech Republic
# 24  2026-06-18  Group Stage          B     Switzerland
# 25  2026-06-18  Group Stage    GROUP K      Uzbekistan
# 26  2026-06-18  Group Stage    GROUP B          Canada
# 27  2026-06-19  Group Stage          D   United States
# 28  2026-06-19  Group Stage    GROUP A          Mexico
# 29  2026-06-19  Group Stage    GROUP C        Scotland
# 30  2026-06-20  Group Stage          D          Turkey
# 31  2026-06-20  Group Stage          E         Germany
# 32  2026-06-20  Group Stage          F     Netherlands
# 33  2026-06-20  Group Stage    GROUP C          Brazil
# 34  2026-06-21  Group Stage          G         Belgium
# 35  2026-06-21  Group Stage          H           Spain
# 36  2026-06-21  Group Stage          H         Uruguay
# 37  2026-06-21  Group Stage    GROUP E         Ecuador
# 38  2026-06-21  Group Stage    GROUP F         Tunisia
# 39  2026-06-22  Group Stage          I          France
# 40  2026-06-22  Group Stage          J       Argentina
# 41  2026-06-22  Group Stage    GROUP G     New Zealand
# 42  2026-06-23  Group Stage          J          Jordan
# 43  2026-06-23  Group Stage          K        Portugal
# 44  2026-06-23  Group Stage          L         England
# 45  2026-06-23  Group Stage    GROUP I          Norway
#
#                  away_team  home_score  away_score                    venue
# 0             South Africa           2           0           Estadio Azteca
# 1   Bosnia and Herzegovina           1           1                BMO Field
# 2           Czech Republic           2           1                     None
# 3              Switzerland           1           1              Lumen Field
# 4                  Morocco           1           1          MetLife Stadium
# 5                 Paraguay           4           1                     None
# 6                  Curaçao           7           1              NRG Stadium
# 7                  Ecuador           1           0  Lincoln Financial Field
# 8                    Japan           2           2             AT&T Stadium
# 9                 Scotland           0           1                     None
# 10                  Turkey           2           0                     None
# 11                   Egypt           1           1              Lumen Field
# 12              Cape Verde           0           0    Mercedes-Benz Stadium
# 13                 Uruguay           1           1        Hard Rock Stadium
# 14                 Tunisia           5           1                     None
# 15                 Senegal           3           1          MetLife Stadium
# 16                  Norway           1           4         Gillette Stadium
# 17             New Zealand           2           2                     None
# 18                  Jordan           3           1             AT&T Stadium
# 19                Congo DR           1           1              NRG Stadium
# 20                 Croatia           4           2             AT&T Stadium
# 21                  Panama           1           0                BMO Field
# 22                 Algeria           3           0                     None
# 23            South Africa           1           1            Estadio Akron
# 24  Bosnia and Herzegovina           4           1                 BC Place
# 25                Colombia           1           3                     None
# 26                   Qatar           6           0                     None
# 27               Australia           2           0  Lincoln Financial Field
# 28             South Korea           1           0                     None
# 29                 Morocco           0           1                     None
# 30                Paraguay           0           1          MetLife Stadium
# 31           Côte d'Ivoire           2           1              NRG Stadium
# 32                  Sweden           5           1              NRG Stadium
# 33                   Haiti           3           0                     None
# 34                    Iran           0           0             SoFi Stadium
# 35            Saudi Arabia           4           0            Estadio Akron
# 36              Cape Verde           2           2        Hard Rock Stadium
# 37                 Curaçao           0           0                     None
# 38                   Japan           0           4                     None
# 39                    Iraq           3           0  Lincoln Financial Field
# 40                 Austria           2           0             AT&T Stadium
# 41                   Egypt           1           3                     None
# 42                 Algeria           1           2             AT&T Stadium
# 43              Uzbekistan           5           0        Arrowhead Stadium
# 44                   Ghana           0           0         Gillette Stadium
# 45                 Senegal           3           2                     None
#      match_date home_team  away_team        source  home_win  draw  away_win  \
# 0    2026-06-23   England      Ghana         1xBet      1.21  7.38     18.50
# 1    2026-06-23   England      Ghana      888sport      9.00  1.08     36.00
# 2    2026-06-23   England      Ghana   BetAnything      1.19  7.70     17.50
# 3    2026-06-23   England      Ghana  BetOnline.ag      1.19  7.70     17.50
# 4    2026-06-23   England      Ghana  Betclic (FR)     13.00  1.03     40.00
# ..          ...       ...        ...           ...       ...   ...       ...
# 648  2026-06-28    Jordan  Argentina   Unibet (NL)     18.00  6.75      1.22
# 649  2026-06-28    Jordan  Argentina   Unibet (SE)     18.00  6.75      1.22
